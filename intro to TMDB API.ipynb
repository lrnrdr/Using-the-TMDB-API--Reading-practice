# %% [markdown]
# ![image.png](attachment:3a22bf76-1fa8-473b-9455-11346689ac63.png)

# %% [markdown]
# ![image.png](attachment:871132ac-c944-4a17-98ef-b45df5542433.png)

# %% [markdown]
# ![image.png](attachment:e14c4faa-742e-4fbf-9e38-5a9a002f0c17.png)

# %% [markdown]
# ![image.png](attachment:45c996aa-579d-4cdf-b75d-ac4f73a971a1.png)

# %%
import json
with open('/Users/rdrlr/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
## Display the keys of the loaded dict
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %% [markdown]
# ![image.png](attachment:a7c4e894-59f3-43e0-9dc1-30a28bc1ee12.png)

# %%
import tmdbsimple as tmdb
tmdb.API_KEY =  login['api-key']

# %% [markdown]
# - After installing tmdbsimple, import the package and set the API_KEY variable to the "API Key(v3 auth)" entry from your Settings page.

# %% [markdown]
# ![image.png](attachment:fc78c83a-ca3f-4d81-a0eb-e741caae50c4.png)

# %%
## make a movie object using the .Movies function from tmdb
movie = tmdb.Movies(603)

# %% [markdown]
# - The data for the movie can be extracted as a dictionary by running the info() method on the movie object.

# %%
## movie objects have a .info dictionary 
info = movie.info()
info
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 ## movie objects have a .info dictionary
# ----> 2 info = movie.info()
#       3 info
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\tmdbsimple\movies.py:73, in Movies.info(self, **kwargs)
#      57 """
#      58 Get the primary information about a movie.
#      59
#    (...)
#      69     A dict representation of the JSON returned from the API.
#      70 """
#      71 path = self._get_id_path('info')
# ---> 73 response = self._GET(path, kwargs)
#      74 self._set_attrs_to_values(response)
#      75 return response
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\tmdbsimple\base.py:110, in TMDB._GET(self, path, params)
#     109 def _GET(self, path, params=None):
# --> 110     return self._request('GET', path, params=params)
#
# ...

# %%
info['budget']
